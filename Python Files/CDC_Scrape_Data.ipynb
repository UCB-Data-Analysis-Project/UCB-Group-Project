# %%
# Import Libaries

import requests
import json
import pandas as pd

#Create function to pull JSON data from CDC API

def CDC_Pull (ThemeId):
    url = "https://nccd.cdc.gov/DHDSPAtlas/proxy.ashx?https://proxy/api/data"
    payload = json.dumps({
      "CountyVersion": "2018",
      "GeographyType": "county",
      "ParentGeographyFilter": "",
      "ThemeClassId": 2,
      "ThemeFilterOptions": [],
      "ThemeId": ThemeId,
      "ThemeSubClassId": 13
    }, indent=4)
    headers = {
      'Content-Type': 'application/json',
      'Cookie': 'TS01ae363a=015d0abe8785e5b669589a99d047712fb1a00a60e1bccd9ee6909e7b2919ccad01d4b5ace6a65d1b843858eac8ee73347cee59aaf5'
    }
    response = requests.request("POST", url, headers=headers, data=payload)
    return response

# Request for the Percent of Black Population by County

Black_Pop_TID = 38

#Ensure correct JSON formatting

res = CDC_Pull(Black_Pop_TID).json()

# Convert RAW JSON into DataFrame

Json_DF_B = pd.json_normalize(res['Data'])

# Rename Value to Correct Column title, will change for every COl
## Display DataFrame

json_df_Black_POP = Json_DF_B.rename(columns={'Value': 'Percent of Black Population'})
json_df_Black_POP
# Out:
#      CensusTractName                      DisplayText    Key ParentText  \
# 0               None                   American Samoa  60000         AS
# 1               None                             Guam  66010         GU
# 2               None                  Mariana Islands  69000         MP
# 3               None  Saint Croix (County Equivalent)  78010         VI
# 4               None   Saint John (County Equivalent)  78020         VI
# ...              ...                              ...    ...        ...
# 3221            None                           Greene  01063         AL
# 3222            None                            Macon  01087         AL
# 3223            None                           Holmes  28051         MS
# 3224            None                        Jefferson  28063         MS
# 3225            None                        Claiborne  28021         MS
#
#       ThemeRangeId  Percent of Black Population
# 0                0                         -1.0
# ...

# %%
# Request for the Percent of Native American Population by County
Native_Pop_TID = 39

#Ensure correct JSON formatting

res_N = CDC_Pull(Native_Pop_TID).json()

# Convert RAW JSON into DataFrame

Json_DF_N = pd.json_normalize(res_N['Data'])
Json_DF_N

# Rename Value to Correct Column title, will change for every COl
## Display DataFrame

json_df_NATIVE_POP = Json_DF_N.rename(columns={'Value': 'Percent of Native American Population'})
json_df_NATIVE_POP
# Out:
#      CensusTractName                      DisplayText    Key ParentText  \
# 0               None                   American Samoa  60000         AS
# 1               None                             Guam  66010         GU
# 2               None                  Mariana Islands  69000         MP
# 3               None  Saint Croix (County Equivalent)  78010         VI
# 4               None   Saint John (County Equivalent)  78020         VI
# ...              ...                              ...    ...        ...
# 3221            None                           Bethel  02050         AK
# 3222            None                          Buffalo  46017         SD
# 3223            None                 Northwest Arctic  02188         AK
# 3224            None                    Oglala Lakota  46102         SD
# 3225            None                         Kusilvak  02158         AK
#
#       ThemeRangeId  Percent of Native American Population
# ...

# %%
# Request for the Percent of White Population by County

White_Pop_TID = 55

#Ensure correct JSON formatting

res_W = CDC_Pull(White_Pop_TID).json()

# Convert RAW JSON into DataFrame

Json_DF_W = pd.json_normalize(res_W['Data'])

# Rename Value to Correct Column title, will change for every COl
## Display DataFrame

json_df_White_POP = Json_DF_W.rename(columns={'Value': 'Percent of White Population'})
json_df_White_POP
# Out:
#      CensusTractName                      DisplayText    Key ParentText  \
# 0               None                   American Samoa  60000         AS
# 1               None                             Guam  66010         GU
# 2               None                  Mariana Islands  69000         MP
# 3               None  Saint Croix (County Equivalent)  78010         VI
# 4               None   Saint John (County Equivalent)  78020         VI
# ...              ...                              ...    ...        ...
# 3221            None                         Highland  51091         VA
# 3222            None                          Webster  54101         WV
# 3223            None                           Hanson  46061         SD
# 3224            None                         Garfield  30033         MT
# 3225            None                           Blaine  31009         NE
#
#       ThemeRangeId  Percent of White Population
# 0                0                         -1.0
# ...

# %%
# Request for the Percent of Hispanic/Latino Population by County

Hispanic_Pop_TID = 56

#Ensure correct JSON formatting

res_H = CDC_Pull(Hispanic_Pop_TID).json()

# Convert RAW JSON into DataFrame

Json_DF_H = pd.json_normalize(res_H['Data'])

# Rename Value to Correct Column title, will change for every COl
## Display DataFrame

json_df_Hispanic_POP = Json_DF_H.rename(columns={'Value': 'Percent of Hispanic/Latino Population'})
json_df_Hispanic_POP
# Out:
#      CensusTractName                      DisplayText    Key ParentText  \
# 0               None                   American Samoa  60000         AS
# 1               None                             Guam  66010         GU
# 2               None                  Mariana Islands  69000         MP
# 3               None  Saint Croix (County Equivalent)  78010         VI
# 4               None   Saint John (County Equivalent)  78020         VI
# ...              ...                              ...    ...        ...
# 3221            None                       Juana Diaz  72075         PR
# 3222            None                          Hatillo  72065         PR
# 3223            None                      Hormigueros  72067         PR
# 3224            None                          Yabucoa  72151         PR
# 3225            None                     Barranquitas  72019         PR
#
#       ThemeRangeId  Percent of Hispanic/Latino Population
# ...

# %%
# Request for the Percent of Asian Population by County
Asian_Pop_TID = 40

#Ensure correct JSON formatting

res_A = CDC_Pull(Asian_Pop_TID).json()

# Convert RAW JSON into DataFrame

Json_DF_A = pd.json_normalize(res_A['Data'])

# Rename Value to Correct Column title, will change for every COl
## Display DataFrame

json_df_Asian_POP = Json_DF_A.rename(columns={'Value': 'Percent of Asian/Pacific Islander Population'})
json_df_Asian_POP
# Out:
#      CensusTractName                      DisplayText    Key ParentText  \
# 0               None                   American Samoa  60000         AS
# 1               None                             Guam  66010         GU
# 2               None                  Mariana Islands  69000         MP
# 3               None  Saint Croix (County Equivalent)  78010         VI
# 4               None   Saint John (County Equivalent)  78020         VI
# ...              ...                              ...    ...        ...
# 3221            None                             Maui  15009         HI
# 3222            None                            Kauai  15007         HI
# 3223            None                   Aleutians West  02016         AK
# 3224            None                         Honolulu  15003         HI
# 3225            None                          Kalawao  15005         HI
#
#       ThemeRangeId  Percent of Asian/Pacific Islander Population
# ...

# %%
# Request for the Percent of Retirement Population by County
Retirement_Pop_TID = 34

#Ensure correct JSON formatting

res_R = CDC_Pull(Retirement_Pop_TID).json()

# Convert RAW JSON into DataFrame

Json_DF_R = pd.json_normalize(res_R['Data'])

# Rename Value to Correct Column title, will change for every COl
## Display DataFrame

json_df_Retirement_POP = Json_DF_R.rename(columns={'Value': 'Percent of Retired Population'})
json_df_Retirement_POP
# Out:
#      CensusTractName                      DisplayText    Key ParentText  \
# 0               None                   American Samoa  60000         AS
# 1               None                             Guam  66010         GU
# 2               None                  Mariana Islands  69000         MP
# 3               None  Saint Croix (County Equivalent)  78010         VI
# 4               None   Saint John (County Equivalent)  78020         VI
# ...              ...                              ...    ...        ...
# 3221            None                           La Paz  04012         AZ
# 3222            None                          Harding  35021         NM
# 3223            None                           Catron  35003         NM
# 3224            None                        Charlotte  12015         FL
# 3225            None                           Sumter  12119         FL
#
#       ThemeRangeId  Percent of Retired Population
# 0                0                           -1.0
# ...

# %%
#Merge Native American and Black Pop Dataframes
Merged_DF = pd.merge(json_df_Black_POP,json_df_NATIVE_POP,left_on='Key',right_on='Key')
#Drop redundent COL.
Merged_DF = Merged_DF.drop(['CensusTractName_y','DisplayText_y','ParentText_y','ThemeRangeId_y'], axis=1)
Merged_DF
# Out:
#      CensusTractName_x                    DisplayText_x    Key ParentText_x  \
# 0                 None                   American Samoa  60000           AS
# 1                 None                             Guam  66010           GU
# 2                 None                  Mariana Islands  69000           MP
# 3                 None  Saint Croix (County Equivalent)  78010           VI
# 4                 None   Saint John (County Equivalent)  78020           VI
# ...                ...                              ...    ...          ...
# 3221              None                           Greene  01063           AL
# 3222              None                            Macon  01087           AL
# 3223              None                           Holmes  28051           MS
# 3224              None                        Jefferson  28063           MS
# 3225              None                        Claiborne  28021           MS
#
#       ThemeRangeId_x  Percent of Black Population  \
# ...

# %%
#Merge White Pop into main DataFrame
Merged_DF2 = pd.merge(Merged_DF,json_df_White_POP,left_on='Key',right_on='Key')
#Drop redundent COL.
Merged_DF2 = Merged_DF2.drop(['CensusTractName','DisplayText','ParentText','ThemeRangeId'], axis=1)
Merged_DF2
# Out:
#      CensusTractName_x                    DisplayText_x    Key ParentText_x  \
# 0                 None                   American Samoa  60000           AS
# 1                 None                             Guam  66010           GU
# 2                 None                  Mariana Islands  69000           MP
# 3                 None  Saint Croix (County Equivalent)  78010           VI
# 4                 None   Saint John (County Equivalent)  78020           VI
# ...                ...                              ...    ...          ...
# 3221              None                           Greene  01063           AL
# 3222              None                            Macon  01087           AL
# 3223              None                           Holmes  28051           MS
# 3224              None                        Jefferson  28063           MS
# 3225              None                        Claiborne  28021           MS
#
#       ThemeRangeId_x  Percent of Black Population  \
# ...

# %%
#Merge Hispanic/Latino Pop into Main Dataframe
Merged_DF3 = pd.merge(Merged_DF2,json_df_Hispanic_POP,left_on='Key',right_on='Key')
#Drop redundent COL.
Merged_DF3 = Merged_DF3.drop(['CensusTractName','DisplayText','ParentText','ThemeRangeId'], axis=1)
Merged_DF3
# Out:
#      CensusTractName_x                    DisplayText_x    Key ParentText_x  \
# 0                 None                   American Samoa  60000           AS
# 1                 None                             Guam  66010           GU
# 2                 None                  Mariana Islands  69000           MP
# 3                 None  Saint Croix (County Equivalent)  78010           VI
# 4                 None   Saint John (County Equivalent)  78020           VI
# ...                ...                              ...    ...          ...
# 3221              None                           Greene  01063           AL
# 3222              None                            Macon  01087           AL
# 3223              None                           Holmes  28051           MS
# 3224              None                        Jefferson  28063           MS
# 3225              None                        Claiborne  28021           MS
#
#       ThemeRangeId_x  Percent of Black Population  \
# ...

# %%
#Merge Asian Pop into Main Dataframe
Merged_DF4 = pd.merge(Merged_DF3,json_df_Asian_POP,left_on='Key',right_on='Key')
#Drop redundent COL.
Merged_DF4 = Merged_DF4.drop(['CensusTractName','DisplayText','ParentText','ThemeRangeId'], axis=1)
Merged_DF4
# Out:
#      CensusTractName_x                    DisplayText_x    Key ParentText_x  \
# 0                 None                   American Samoa  60000           AS
# 1                 None                             Guam  66010           GU
# 2                 None                  Mariana Islands  69000           MP
# 3                 None  Saint Croix (County Equivalent)  78010           VI
# 4                 None   Saint John (County Equivalent)  78020           VI
# ...                ...                              ...    ...          ...
# 3221              None                           Greene  01063           AL
# 3222              None                            Macon  01087           AL
# 3223              None                           Holmes  28051           MS
# 3224              None                        Jefferson  28063           MS
# 3225              None                        Claiborne  28021           MS
#
#       ThemeRangeId_x  Percent of Black Population  \
# ...

# %%
#Merge Retirement Pop into Main Dataframe
Merged_DF_Demo_Final = pd.merge(Merged_DF4,json_df_Retirement_POP,left_on='Key',right_on='Key')
#Drop redundent COL.
Merged_DF_Demo_Final = Merged_DF_Demo_Final.drop(['CensusTractName','DisplayText','ParentText','ThemeRangeId'], axis=1)
Merged_DF_Demo_Final
# Out:
#      CensusTractName_x                    DisplayText_x    Key ParentText_x  \
# 0                 None                   American Samoa  60000           AS
# 1                 None                             Guam  66010           GU
# 2                 None                  Mariana Islands  69000           MP
# 3                 None  Saint Croix (County Equivalent)  78010           VI
# 4                 None   Saint John (County Equivalent)  78020           VI
# ...                ...                              ...    ...          ...
# 3221              None                           Greene  01063           AL
# 3222              None                            Macon  01087           AL
# 3223              None                           Holmes  28051           MS
# 3224              None                        Jefferson  28063           MS
# 3225              None                        Claiborne  28021           MS
#
#       ThemeRangeId_x  Percent of Black Population  \
# ...
